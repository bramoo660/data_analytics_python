# %% [markdown]
# ### Car Servicing Project

# %% [markdown]
# ## Details about the Project
# - Importing Libraries
# - Loading and creating copy of the data
# - overview and understanding the Data Frame
#     - index
#     - columns
#     - size
# - Checking total number of Rows and Columns
#     - ndim
#     - Indexing and Selecting Rows
#     -  Head
#     -  Tail
# - Checking for Uniques Instances of the Columns
# - Data Preprocessing
#     - Replacing missing valuesm- issing values
# Final Check on Data for
# - EDA Exploratory Analysis
#    - ratory Analysis
# Descriptive Analysis

# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\ybrim\AppData\Local\Temp\ipykernel_8092\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Loading the Data

# %%
car_data = pd.read_csv('Datasets/car_servicing.csv', encoding = 'latin-1')

# %%
car_data
# Out:
#              dateCrawled                                               name  \
# 0       17/03/2016 16:54                                 GOLF_4_1_4__3TÜRER
# 1       31/03/2016 17:25                     Skoda_Fabia_1.4_TDI_PD_Classic
# 2       04/04/2016 17:36  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 3       01/04/2016 20:48                        Peugeot_206_CC_110_Platinum
# 4       21/03/2016 18:54                       VW_Derby_Bj_80__Scheunenfund
# ...                  ...                                                ...
# 260960  19/03/2016 19:53                                       turbo_defekt
# 260961  27/03/2016 20:36                 Opel_Zafira_1.6_Elegance_TÜV_12/16
# 260962  05/03/2016 19:56              Smart_smart_leistungssteigerung_100ps
# 260963  19/03/2016 18:57                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 260964  07/03/2016 19:39       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %% [markdown]
# ## Creating copy of the Data

# %%
df = car_data.copy()

# %% [markdown]
# ## Data Overview
# - index
# - columns
# - size
# - checking total number of rows and columns
# - ndim

# %%
car_data.index
# Out:
# RangeIndex(start=0, stop=260965, step=1)

# %%
car_data.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen'],
#       dtype='object')

# %%
car_data.size
# Out:
# 4958335

# %%
print(f"=> Total Number of Rows: {car_data.shape[0]} => Total Number of Columns: {car_data.shape[1]}")
# Out:
# => Total Number of Rows: 260965 => Total Number of Columns: 19

# %%
car_data.ndim
# Out:
# 2

# %% [markdown]
# ## Indexing and selecting Rows
# - head
# - tail
# - dtypes

# %%
car_data.head()
# Out:
#         dateCrawled                                               name  \
# 0  17/03/2016 16:54                                 GOLF_4_1_4__3TÜRER
# 1  31/03/2016 17:25                     Skoda_Fabia_1.4_TDI_PD_Classic
# 2  04/04/2016 17:36  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 3  01/04/2016 20:48                        Peugeot_206_CC_110_Platinum
# 4  21/03/2016 18:54                       VW_Derby_Bj_80__Scheunenfund
#
#     seller offerType  price abtest vehicleType  yearOfRegistration gearbox  \
# 0  private     offer   1500   test   small car                2001  manual
# 1  private     offer   3600   test   small car                2008  manual
# 2  private     offer    650   test   limousine                1995  manual
# 3  private     offer   2200   test      cabrio                2004  manual
# 4  private     offer      0   test   limousine                1980  manual
#
#    powerPS    model  kilometer  monthOfRegistration fuelType       brand  \
# ...

# %%
car_data.tail()
# Out:
#              dateCrawled                                          name  \
# 260960  19/03/2016 19:53                                  turbo_defekt
# 260961  27/03/2016 20:36            Opel_Zafira_1.6_Elegance_TÜV_12/16
# 260962  05/03/2016 19:56         Smart_smart_leistungssteigerung_100ps
# 260963  19/03/2016 18:57            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 260964  07/03/2016 19:39  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#          seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 260960  private     offer   3200  control   limousine                2004
# 260961  private     offer   1150  control         bus                2000
# 260962  private     offer   1199     test      cabrio                2000
# 260963  private     offer   9200     test         bus                1996
# 260964  private     offer  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# ...

# %%
car_data.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# postalCode              int64
# lastSeen               object
# dtype: object

# %% [markdown]
# ## Checking for Unique Instances
# - name
# - model

# %%
print(np.unique(car_data['lastSeen']))
# Out:
# ['01/04/2016 0:15' '01/04/2016 0:16' '01/04/2016 0:17' ...
#  '31/03/2016 9:53' '31/03/2016 9:55' '31/03/2016 9:57']

# %% [markdown]
# ## Data Preprocessing
# - Checking Data types Using the dtype function
# - Group data types into categorical and non-categorical

# %%
car_data.isnull()
# Out:
#         dateCrawled   name  seller  offerType  price  abtest  vehicleType  \
# 0             False  False   False      False  False   False        False
# 1             False  False   False      False  False   False        False
# 2             False  False   False      False  False   False        False
# 3             False  False   False      False  False   False        False
# 4             False  False   False      False  False   False        False
# ...             ...    ...     ...        ...    ...     ...          ...
# 260960        False  False   False      False  False   False        False
# 260961        False  False   False      False  False   False        False
# 260962        False  False   False      False  False   False        False
# 260963        False  False   False      False  False   False        False
# 260964        False  False   False      False  False   False        False
#
#         yearOfRegistration  gearbox  powerPS  model  kilometer  \
# ...

# %% [markdown]
# ## Grouping Data into Categorical and Numerical
