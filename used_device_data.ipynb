# %% [markdown]
# ## Data Analytics Final Project

# %% [markdown]
# ## Goal: Is to be able to predict/estimate the prices of used devices based on the available features

# %% [markdown]
# ## Details about the Project
# - Importing Libraries
# - Loading and creating copy of the data
# - overview and understanding the Data Frame
#   - index
#   - columns
#   - size
#   - Checking total number of Rows and Columns
#   - ndim
# - Indexing and Selecting Rows
#    - Head
#    - Tail
# - Checking for Uniques Instances of the Columns
# - Data Preprocessing
#    - Replacing missing values
#    - Final Check on Data for Missing Values
# - EDA Exploratory Analysis
#   - Descriptive Analysis

# %% [markdown]
# ### Find Below the Imported Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Data

# %%
device_data = pd.read_csv("Datasets/used_device_data.csv")

# %%
device_data
# Out:
#      brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0         Honor  Android        14.50  yes   no            13.0
# 1         Honor  Android        17.30  yes  yes            13.0
# 2         Honor  Android        16.69  yes  yes            13.0
# 3         Honor  Android        25.50  yes  yes            13.0
# 4         Honor  Android        15.32  yes   no            13.0
# ...         ...      ...          ...  ...  ...             ...
# 3449       Asus  Android        15.34  yes   no             NaN
# 3450       Asus  Android        15.24  yes   no            13.0
# 3451    Alcatel  Android        15.80  yes   no            13.0
# 3452    Alcatel  Android        15.80  yes   no            13.0
# 3453    Alcatel  Android        12.83  yes   no            13.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0                  5.0        64.0  3.0   3020.0   146.0          2020
# ...

# %% [markdown]
# ### Creating a Copy of Data

# %%
## creating a copy

df = device_data.copy()

# %% [markdown]
# ### Data Overview
# - Index
# - Columns
# - Size
# - Checking total number of Rows and Columns
# - ndim
# - info

# %%
device_data.index
# Out:
# RangeIndex(start=0, stop=3454, step=1)

# %%
device_data.columns
# Out:
# Index(['brand_name', 'os', 'screen_size', '4g', '5g', 'main_camera_mp',
#        'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'used_price'],
#       dtype='object')

# %%
device_data.size
# Out:
# 48356

# %%
print(f"=> Total Number of Rows: {device_data.shape[0]} => Total Number of Columns: {device_data.shape[1]}")
# Out:
# => Total Number of Rows: 3454 => Total Number of Columns: 14

# %%
device_data.ndim
# Out:
# 2

# %%
device_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand_name        3454 non-null   object
#  1   os                3454 non-null   object
#  2   screen_size       3454 non-null   float64
#  3   4g                3454 non-null   object
#  4   5g                3454 non-null   object
#  5   main_camera_mp    3275 non-null   float64
#  6   selfie_camera_mp  3452 non-null   float64
#  7   int_memory        3450 non-null   float64
#  8   ram               3450 non-null   float64
#  9   battery           3448 non-null   float64
#  10  weight            3447 non-null   float64
#  11  release_year      3454 non-null   int64
#  12  days_used         3454 non-null   int64
#  13  used_price        3454 non-null   float64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 377.9+ KB

# %% [markdown]
# ## Indexing and Selecting Rows
# - head
# - tail

# %%
device_data.head()
# Out:
#   brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0      Honor  Android        14.50  yes   no            13.0
# 1      Honor  Android        17.30  yes  yes            13.0
# 2      Honor  Android        16.69  yes  yes            13.0
# 3      Honor  Android        25.50  yes  yes            13.0
# 4      Honor  Android        15.32  yes   no            13.0
#
#    selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0               5.0        64.0  3.0   3020.0   146.0          2020
# 1              16.0       128.0  8.0   4300.0   213.0          2020
# 2               8.0       128.0  8.0   4200.0   213.0          2020
# 3               8.0        64.0  6.0   7250.0   480.0          2020
# 4               8.0        64.0  3.0   5000.0   185.0          2020
#
#    days_used  used_price
# 0        127       74.26
# 1        325      174.53
# 2        162      165.85
# 3        345      169.93
# 4        293       80.64

# %%
device_data.tail()
# Out:
#      brand_name       os  screen_size   4g  5g  main_camera_mp  \
# 3449       Asus  Android        15.34  yes  no             NaN
# 3450       Asus  Android        15.24  yes  no            13.0
# 3451    Alcatel  Android        15.80  yes  no            13.0
# 3452    Alcatel  Android        15.80  yes  no            13.0
# 3453    Alcatel  Android        12.83  yes  no            13.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 3449               8.0        64.0  6.0   5000.0   190.0          2019
# 3450               8.0       128.0  8.0   4000.0   200.0          2018
# 3451               5.0        32.0  3.0   4000.0   165.0          2020
# 3452               5.0        32.0  2.0   4000.0   160.0          2020
# 3453               5.0        16.0  2.0   4000.0   168.0          2020
#
#       days_used  used_price
# 3449        232       89.33
# 3450        541      154.12
# 3451        201       78.05
# 3452        149       77.46
# ...

# %% [markdown]
# ## Checking for unique Instances of columns with the uniques attrib
# - main_camera_mp
# - selfie_camera_mp
# - int_memory
# - ram
# - battery
# - weight

# %%
print(np.unique(device_data['main_camera_mp']))
# Out:
# [ 0.08  0.3   1.    1.2   1.3   2.    3.    3.15  4.    5.    6.5   6.7
#   8.    8.1  10.   10.5  12.   12.2  12.3  12.5  12.6  13.   13.1  14.5
#  16.   16.3  18.   19.   20.   20.1  20.2  20.7  21.   21.2  21.5  22.5
#  22.6  23.   24.   41.   48.     nan]

# %%
print(np.unique(device_data['selfie_camera_mp']))
# Out:
# [ 0.    0.3   0.65  0.9   1.    1.1   1.2   1.25  1.3   1.6   1.8   1.9
#   2.    2.1   2.2   3.    3.5   3.7   4.    5.    5.1   7.    8.    9.
#  10.   10.5  12.   13.   14.   14.5  16.   16.3  18.   20.   24.   25.
#  32.     nan]

# %%
print(np.unique(device_data['int_memory']))
# Out:
# [1.000e-02 6.000e-02 1.000e-01 2.000e-01 5.000e-01 4.000e+00 8.000e+00
#  1.600e+01 2.400e+01 3.200e+01 6.400e+01 1.280e+02 2.560e+02 5.120e+02
#  1.024e+03       nan]

# %%
print(np.unique(device_data['ram']))
# Out:
# [ 0.02  0.03  0.25  0.5   1.    1.5   2.    3.    4.    6.    8.   12.
#    nan]

# %%
print(np.unique(device_data['battery']))
# Out:
# [ 500.   620.   750.   800.   820.   850.   950.  1000.  1010.  1020.
#  1030.  1100.  1110.  1150.  1170.  1200.  1230.  1280.  1300.  1350.
#  1400.  1420.  1430.  1450.  1470.  1500.  1510.  1540.  1560.  1600.
#  1624.  1625.  1630.  1650.  1700.  1715.  1730.  1750.  1760.  1780.
#  1785.  1800.  1810.  1820.  1821.  1830.  1840.  1850.  1860.  1880.
#  1900.  1905.  1920.  1940.  1950.  1960.  1975.  1980.  2000.  2020.
#  2030.  2040.  2050.  2060.  2070.  2100.  2110.  2125.  2130.  2140.
#  2150.  2180.  2200.  2210.  2230.  2250.  2256.  2260.  2280.  2300.
#  2320.  2330.  2350.  2370.  2390.  2400.  2410.  2420.  2430.  2440.
#  2450.  2460.  2470.  2480.  2500.  2515.  2520.  2525.  2530.  2540.
#  2550.  2560.  2580.  2600.  2610.  2620.  2630.  2640.  2650.  2658.
#  2660.  2670.  2680.  2691.  2700.  2705.  2710.  2716.  2730.  2750.
#  2760.  2770.  2800.  2820.  2840.  2850.  2860.  2865.  2870.  2880.
# ...

# %%
print(np.unique(device_data['weight']))
# Out:
# [ 69.    75.    77.9   78.2   78.4   78.6   79.    80.    81.    82.6
#   83.6   85.    86.5   87.5   88.1   88.2   89.    89.2   89.3   89.6
#   90.    90.5   91.    91.3   91.8   92.    93.    95.    96.    97.
#   97.3   97.7   98.    98.2   98.6   98.9   99.5   99.8  100.   100.5
#  100.6  101.   101.1  101.3  102.   103.   103.3  103.7  104.5  104.6
#  105.   106.   107.   107.6  108.   109.   110.   110.2  110.3  110.6
#  111.4  112.   113.   113.4  113.6  114.   114.5  115.   115.3  115.35
#  115.4  115.5  116.   117.   117.4  117.9  118.   118.2  118.5  118.7
#  118.8  118.9  119.   119.1  119.5  119.8  120.   120.6  121.   121.1
#  121.9  122.   122.5  122.7  123.   123.3  123.8  123.9  124.   124.4
#  124.9  125.   125.3  125.9  126.   126.5  126.6  127.   127.6  127.9
#  128.   128.5  128.7  129.   129.4  129.6  130.   130.1  130.3  130.4
#  130.5  131.   131.5  131.9  132.   132.5  133.   133.2  133.5  134.
# ...

# %%
device_data.isnull().sum()
# Out:
# brand_name            0
# os                    0
# screen_size           0
# 4g                    0
# 5g                    0
# main_camera_mp      179
# selfie_camera_mp      2
# int_memory            4
# ram                   4
# battery               6
# weight                7
# release_year          0
# days_used             0
# used_price            0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing
# - Checking Data types Using the dtype function
# - Analytical summary of dataset using the describe function
# - Group data types into categorical and non-categorical
# - Filling in Missing Values Using MEAN Function

# %% [markdown]
# #### Check for Data types

# %%
##device_data.dtypes

# %%
# Analytical summary of the Dataset

##device_data.describe(include = 'all')

# %% [markdown]
# #### Grouping Data into Types

# %%
numerical = ['screen_size', 'main_camera_mp', 'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight', 'release_year', 'days_used', 'used_price']

categorical = ['brand_name', 'os', '4g', '5g']

# %%
device_data[numerical]
# Out:
#       screen_size  main_camera_mp  selfie_camera_mp  int_memory  ram  battery  \
# 0           14.50            13.0               5.0        64.0  3.0   3020.0
# 1           17.30            13.0              16.0       128.0  8.0   4300.0
# 2           16.69            13.0               8.0       128.0  8.0   4200.0
# 3           25.50            13.0               8.0        64.0  6.0   7250.0
# 4           15.32            13.0               8.0        64.0  3.0   5000.0
# ...           ...             ...               ...         ...  ...      ...
# 3449        15.34             NaN               8.0        64.0  6.0   5000.0
# 3450        15.24            13.0               8.0       128.0  8.0   4000.0
# 3451        15.80            13.0               5.0        32.0  3.0   4000.0
# 3452        15.80            13.0               5.0        32.0  2.0   4000.0
# 3453        12.83            13.0               5.0        16.0  2.0   4000.0
#
# ...

# %%
device_data[categorical]
# Out:
#      brand_name       os   4g   5g
# 0         Honor  Android  yes   no
# 1         Honor  Android  yes  yes
# 2         Honor  Android  yes  yes
# 3         Honor  Android  yes  yes
# 4         Honor  Android  yes   no
# ...         ...      ...  ...  ...
# 3449       Asus  Android  yes   no
# 3450       Asus  Android  yes   no
# 3451    Alcatel  Android  yes   no
# 3452    Alcatel  Android  yes   no
# 3453    Alcatel  Android  yes   no
#
# [3454 rows x 4 columns]

# %%
device_data.isnull()
# Out:
#       brand_name     os  screen_size     4g     5g  main_camera_mp  \
# 0          False  False        False  False  False           False
# 1          False  False        False  False  False           False
# 2          False  False        False  False  False           False
# 3          False  False        False  False  False           False
# 4          False  False        False  False  False           False
# ...          ...    ...          ...    ...    ...             ...
# 3449       False  False        False  False  False            True
# 3450       False  False        False  False  False           False
# 3451       False  False        False  False  False           False
# 3452       False  False        False  False  False           False
# 3453       False  False        False  False  False           False
#
#       selfie_camera_mp  int_memory    ram  battery  weight  release_year  \
# 0                False       False  False    False   False         False
# ...

# %% [markdown]
# ## Value Count

# %%
device_data['brand_name'].value_counts()
# Out:
# brand_name
# Others        502
# Samsung       341
# Huawei        251
# LG            201
# Lenovo        171
# ZTE           140
# Xiaomi        132
# Oppo          129
# Asus          122
# Alcatel       121
# Micromax      117
# Vivo          117
# Honor         116
# HTC           110
# Nokia         106
# Motorola      106
# Sony           86
# Meizu          62
# Gionee         56
# Acer           51
# XOLO           49
# Panasonic      47
# Realme         41
# Apple          39
# Lava           36
# Celkon         33
# Spice          30
# Karbonn        29
# Coolpad        22
# BlackBerry     22
# Microsoft      22
# OnePlus        22
# Google         15
# Infinix        10
# Name: count, dtype: int64

# %%
device_data.isnull().sum()
# Out:
# brand_name            0
# os                    0
# screen_size           0
# 4g                    0
# 5g                    0
# main_camera_mp      179
# selfie_camera_mp      2
# int_memory            4
# ram                   4
# battery               6
# weight                7
# release_year          0
# days_used             0
# used_price            0
# dtype: int64

# %% [markdown]
# ## Filling in Missing Values using mean attrib in following
# - main_camera_mp
# - selfie_camera_mp
# - int_memory
# - ram
# - battery
# - weight
# #### Checking to see if missing values still exit

# %%
mean_mcm = device_data['main_camera_mp'].mean()
device_data['main_camera_mp'] = device_data['main_camera_mp'].fillna(mean_mcm)

# %%
mean_scm = device_data['selfie_camera_mp'].mean()
device_data['selfie_camera_mp'] = device_data['selfie_camera_mp'].fillna(mean_scm)

# %%
mean_im = device_data['int_memory'].mean()
device_data['int_memory'] = device_data['int_memory'].fillna(mean_im)

# %%
mean_rm = device_data['ram'].mean()
device_data['ram'] = device_data['ram'].fillna(mean_rm)

# %%
mean_bt = device_data['battery'].mean()
device_data['battery'] = device_data['battery'].fillna(mean_bt)

# %%
mean_wt = device_data['weight'].mean()
device_data['weight'] = device_data['weight'].fillna(mean_wt)

# %% [markdown]
# #### Final Check on Data for Missing Values

# %%
## Display the new data table
device_data.isnull().sum()
# Out:
# brand_name          0
# os                  0
# screen_size         0
# 4g                  0
# 5g                  0
# main_camera_mp      0
# selfie_camera_mp    0
# int_memory          0
# ram                 0
# battery             0
# weight              0
# release_year        0
# days_used           0
# used_price          0
# dtype: int64

# %% [markdown]
# ### EDA Exploratory Analysis on each
# - Descriptive Analysis
# - correlation

# %%
device_data.describe()
# Out:
#        screen_size  main_camera_mp  selfie_camera_mp   int_memory  \
# count  3454.000000     3454.000000       3454.000000  3454.000000
# mean     13.713115        9.460208          6.554229    54.573099
# std       3.805280        4.688986          6.968353    84.923140
# min       5.080000        0.080000          0.000000     0.010000
# 25%      12.700000        5.000000          2.000000    16.000000
# 50%      12.830000        9.460208          5.000000    32.000000
# 75%      15.340000       13.000000          8.000000    64.000000
# max      30.710000       48.000000         32.000000  1024.000000
#
#                ram      battery       weight  release_year    days_used  \
# count  3454.000000  3454.000000  3454.000000   3454.000000  3454.000000
# mean      4.036122  3133.402697   182.751871   2015.965258   674.869716
# std       1.364314  1298.553176    88.323566      2.298455   248.580166
# min       0.020000   500.000000    69.000000   2013.000000    91.000000
# ...

# %% [markdown]
# ### Creation of variables and Correlations

# %%
num_df = device_data[numerical]

cat_df = device_data[categorical]

# %%
corr_device_data = num_df.corr()

corr_device_data
# Out:
#                   screen_size  main_camera_mp  selfie_camera_mp  int_memory  \
# screen_size          1.000000        0.148764          0.271631    0.071108
# main_camera_mp       0.148764        1.000000          0.395164    0.018254
# selfie_camera_mp     0.271631        0.395164          1.000000    0.296273
# int_memory           0.071108        0.018254          0.296273    1.000000
# ram                  0.273746        0.228691          0.477166    0.121853
# battery              0.811192        0.240908          0.369572    0.117541
# weight               0.828743       -0.087597         -0.004995    0.014939
# release_year         0.364223        0.327828          0.690785    0.235247
# days_used           -0.291723       -0.133612         -0.552502   -0.242499
# used_price           0.529275        0.434729          0.613803    0.377939
#
#                        ram   battery    weight  release_year  days_used  \
# ...

# %% [markdown]
# #### Importing another Pandas Library at top of Import section to Aid in our Descriptive Analysis

# %%
plt.scatter(device_data['screen_size'], device_data['used_price'], c = 'blue')

plt.title('Relationship Between Screen size and Price')

plt.ylabel('Price (Dollars)')

plt.xlabel('screen size (Diagonal)')

plt.savefig('Screen_price_rel.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# From the ABOVE data we have, we realise that screen sizes between 10inches and 18inches
# are on high demand due to the price moderation.

# %%
device_data.hist(figsize = (20, 30))
# Out:
# array([[<Axes: title={'center': 'screen_size'}>,
#         <Axes: title={'center': 'main_camera_mp'}>,
#         <Axes: title={'center': 'selfie_camera_mp'}>],
#        [<Axes: title={'center': 'int_memory'}>,
#         <Axes: title={'center': 'ram'}>,
#         <Axes: title={'center': 'battery'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'days_used'}>],
#        [<Axes: title={'center': 'used_price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
## frequency distribution of device brand names

plt.figure(figsize=(30,30))
sns.countplot(x=device_data['brand_name'])

plt.title('Countplot distribution of Price in relation to brand_name.')

plt.ylabel('brand')

plt.xlabel('Price')

plt.savefig('Hist_price_rel.png')

plt.show()

# %%
# data_df = data_df.drop(['os', 'int_memory', 'days_used'], axis = 1)
# data_df.head(5)

cat = ['brand_name', 'int_memory', 'battery', 'ram', 'used_price']
z = device_data[cat]
z
# Out:
#      brand_name  int_memory  battery  ram  used_price
# 0         Honor        64.0   3020.0  3.0       74.26
# 1         Honor       128.0   4300.0  8.0      174.53
# 2         Honor       128.0   4200.0  8.0      165.85
# 3         Honor        64.0   7250.0  6.0      169.93
# 4         Honor        64.0   5000.0  3.0       80.64
# ...         ...         ...      ...  ...         ...
# 3449       Asus        64.0   5000.0  6.0       89.33
# 3450       Asus       128.0   4000.0  8.0      154.12
# 3451    Alcatel        32.0   4000.0  3.0       78.05
# 3452    Alcatel        32.0   4000.0  2.0       77.46
# 3453    Alcatel        16.0   4000.0  2.0       62.31
#
# [3454 rows x 5 columns]

# %%
sns.barplot( data = z , y='brand_name', x='battery', errorbar=None)# hue = 'used_price')
# Out:
# <Axes: xlabel='battery', ylabel='brand_name'>

# %% [markdown]
# #### Considering the type of data we have, we realised that when people are to buy a device, they dont have taste for features of the phone
