# %% [markdown]
# ## Data Analytics Final Project

# %% [markdown]
# ## Step 0 : Imports and Reading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
data_df = pd.read_csv('Datasets/sales_data.csv')
df = data_df.copy()

# %% [markdown]
# ## Step 1: Data Understanding
# - Dataframe Shape
# - head and tail
# - Dtypes
# - describe
# - Columns

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
#Display our Columns
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Step 2: Data Preparation
# - Dropping Irrelevant Columns and Rows
# - Identifying Duplicated Columns

# %%
# # Dropping some columns by commenting out the unwanted columns
df = df[[#'Date',
         #'Day', 'Month', 
                'Customer_Age',
                #'Age_Group',
         'Customer_Gender', 'Country', 'State',
                #'Product_Category', 
               #'Sub_Category','Cost',
         'Product', 
           'Year','Order_Quantity', 'Unit_Cost','Unit_Price','Profit','Revenue']].copy()

# %%
##Display the data types after Dropping some columns
df.dtypes
# Out:
# Customer_Age        int64
# Customer_Gender    object
# Country            object
# State              object
# Product            object
# Year                int64
# Order_Quantity      int64
# Unit_Cost           int64
# Unit_Price          int64
# Profit              int64
# Revenue             int64
# dtype: object

# %%
## Dropping some rows in our dataset data[1001:113036] 
#df = df.drop[1000:113036].copy() 
df.drop(df.index[1000 : 113036], axis=0, inplace=True)

# %%
df.shape
# Out:
# (1000, 11)

# %%
## Checking for missing and unique values 

##fortunately the Dataframe has no missing unique values

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Grouping Data into Numerical and Categorical

# %%
numerical = ['Day', 'Order_Quantity', 'Unit_Price', 'Profit', 'Cost', 'Revenue', 'Customer_Age']

categorical = ['Date', 'Month', 'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product', 'Year']

# %% [markdown]
# ## Descriptive Analysis
# - Total Revenue, Highest Revenue, Lowest Revenue

# %%
## Total Revenue

df['Revenue'].sum()
# Out:
# 85271008

# %%
## Highest Revenue

df['Revenue'].min()
# Out:
# 2

# %%
df['Revenue'].max()
# Out:
# 58074

# %%
cat_cols = ['Date','Month','Customer_Gender', 'Country','State','Product_Category', 'Sub_Category','Product','Customer_Gender','Year', 'Age_Group']

num_cols = ['Day','Order_Quantity', 'Unit_Price','Profit','Cost', 'Revenue', 'Customer_Age']

# %%
cat_df = df[cat_cols]

num_df = df[num_cols]

# %%
corr_df = num_df.corr()

corr_df
# Out:
#                      Day  Order_Quantity  Unit_Price    Profit      Cost  \
# Day             1.000000       -0.002412    0.003207  0.004623  0.003329
# Order_Quantity -0.002412        1.000000   -0.515925 -0.238863 -0.340382
# Unit_Price      0.003207       -0.515925    1.000000  0.749870  0.826301
# Profit          0.004623       -0.238863    0.749870  1.000000  0.902233
# Cost            0.003329       -0.340382    0.826301  0.902233  1.000000
# Revenue         0.003853       -0.312895    0.818522  0.956572  0.988758
# Customer_Age   -0.014296        0.026887   -0.020262  0.004319 -0.016013
#
#                  Revenue  Customer_Age
# Day             0.003853     -0.014296
# Order_Quantity -0.312895      0.026887
# Unit_Price      0.818522     -0.020262
# Profit          0.956572      0.004319
# Cost            0.988758     -0.016013
# Revenue         1.000000     -0.009326
# Customer_Age   -0.009326      1.000000

# %%
# Relationship analysis
sns.heatmap(corr_df, xticklabels= corr_df.columns, yticklabels= corr_df.columns, annot = True)
plt.title('correlation between numerical values')
# Out:
# Text(0.5, 1.0, 'correlation between numerical values')

# %%
# CORELATION
sns.pairplot(corr_df)
plt.title('Pairplot Showing the correlations')
# Out:
# Text(0.5, 1.0, 'Pairplot Showing the correlations')

# %%
#SCATTER PLOT TO SHOW RELATIONSHIP BETWEEN PROFIT AND REVENUE AGAINST COST
sns.relplot(x='Profit', y='Cost', hue= 'Revenue', data=df)
plt.title('RELATIONSHIP BETWEEN PROFIT AND REVENUE AGAINST COST')
# Out:
# Text(0.5, 1.0, 'RELATIONSHIP BETWEEN PROFIT AND REVENUE AGAINST COST')

# %%
sns.distplot(df['Revenue'])
# Out:
# C:\Users\ybrim\AppData\Local\Temp\ipykernel_6464\118599645.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Revenue'])
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
sns.catplot(df['Revenue'], kind='box')

# %%
# Value count of the countries 

country= pd.crosstab(index=df["Country"], columns='count')
country
# Out:
# col_0           count
# Country
# Australia       23936
# Canada          14178
# France          10998
# Germany         11098
# United Kingdom  13620
# United States   39206

# %%
country.plot(kind="bar", figsize=(8,8))

plt.title('Countries per Distribution')

plt.ylabel('Customers')

plt.xlabel('Country')
# Out:
# Text(0.5, 0, 'Country')

# %% [markdown]
# ## Pie Chart showing country by % distrubution

# %%
Country= df['Country'].value_counts()
plt.figure(figsize =(15, 15))

# %%
plt.pie(Country, labels = Country.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'smaller'}, radius=0.7)
plt.title('Country by % Distribution')
# Out:
# Text(0.5, 1.0, 'Country by % Distribution')

# %%
# Value count for 


data_team= pd.crosstab(index=df["Product_Category"], columns='count')

data_team.plot(kind="bar")

plt.title('Product Category by Distribution')

plt.ylabel('Total')

plt.xlabel('Products')

plt.savefig('Product_category_rel.png')

plt.show()

# %% [markdown]
# ## Pie chart showing Product by Category

# %%
Product_Category= df['Product_Category'].value_counts()
plt.figure(figsize =(10, 10))

# %%
plt.pie(Product_Category, labels = Product_Category.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'smaller'}, radius=1.0)
plt.title('Product By Category')
# Out:
# Text(0.5, 1.0, 'Product By Category')

# %% [markdown]
# ## Individual Product Category break down

# %%
sub_cat= pd.crosstab(index=df["Sub_Category"], columns='count')

sub_cat.plot(kind="bar", figsize=(15,15))

plt.title("Sales by Category Distribution")

plt.ylabel("Sales")

plt.xlabel("Product by Category")
# Out:
# Text(0.5, 0, 'Product by Category')

# %% [markdown]
# ## Pie chart showing Sub Category of Product

# %%
Sub_Category= df['Sub_Category'].value_counts()
plt.figure(figsize =(50, 50))

# %%
plt.pie(Sub_Category, labels = Sub_Category.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'larger'}, radius=2.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d6d6f8b490>,
# ...
#  [Text(-2.6690659448824796, -0.6622589990846453, 'Tires and Tubes'),
#   Text(0.15117083761009603, -2.745841834093192, 'Bottles and Cages'),
#   Text(2.1010109818676015, -1.774331664056001, 'Road Bikes'),
#   Text(2.749866233284, 0.02712377268126575, 'Helmets'),
#   Text(2.279184524418156, 1.538771556681753, 'Mountain Bikes'),
#   Text(1.4696905662680684, 2.3243299334265446, 'Jerseys'),
#   Text(0.7485547587721535, 2.6461605720589905, 'Caps'),
#   Text(0.11683544676833157, 2.7475169659855503, 'Fenders'),
#   Text(-0.47159332187036807, 2.7092618438916665, 'Touring Bikes'),
#   Text(-0.9423745244282029, 2.58349187258422, 'Gloves'),
#   Text(-1.2564681024039837, 2.4461782248318156, 'Cleaners'),
#   Text(-1.4942699522835754, 2.308605057107526, 'Shorts'),
#   Text(-1.689075013202839, 2.1701441426259755, 'Hydration Packs'),
#   Text(-1.833158956342461, 2.0498849335466174, 'Socks'),
#   Text(-1.9488563434387485, 1.9402213669162989, 'Vests'),
# ...

# %%
State = pd.crosstab(index=df["State"], columns='count')

State.plot(kind="bar", figsize=(15,15))

plt.title("Sales Distribution by State ")

plt.ylabel("Products per sale")

plt.xlabel("States")
# Out:
# Text(0.5, 0, 'States')

# %% [markdown]
# ## Sales per % Distribution by State

# %%
State= df['State'].value_counts()
plt.figure(figsize =(500, 500))

# %%
plt.pie(State, labels = State.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'larger'}, radius=2.5)
#plt.title('Sub Category of Product')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d6b049b490>,
# ...
#  [Text(-2.7424368446151206, 0.20381401644013764, 'California'),
#   Text(-1.6172695091531375, -2.2241716064107035, 'British Columbia'),
#   Text(0.38961726853302164, -2.7222597936385253, 'England'),
#   Text(2.0362651619925907, -1.848276004836748, 'Washington'),
#   Text(2.725125059138742, -0.3690439161591287, 'New South Wales'),
#   Text(2.6086820149886862, 0.8702172973887432, 'Victoria'),
#   Text(2.212164743188127, 1.6336545378369958, 'Oregon'),
#   Text(1.648265144378625, 2.20130007355347, 'Queensland'),
#   Text(1.1229678792844255, 2.510267543927428, 'Saarland'),
#   Text(0.7457595662680909, 2.6469496914976736, 'Nordrhein-Westfalen'),
#   Text(0.3819153672761823, 2.7233509968856935, 'Hessen'),
#   Text(0.023013800078750927, 2.749903701042263, 'Seine (Paris)'),
#   Text(-0.29467500060167373, 2.7341665355315143, 'Hamburg'),
#   Text(-0.5603252905064073, 2.6923104517902297, 'Seine Saint Denis'),
# ...

# %%
sns.barplot(data = df, y='Revenue', x='Age_Group', hue='Country', errorbar=None)
plt.title('Order Quantity Distribution against Age Group.')
plt.xlabel('Age Group')
plt.ylabel('Quantity')

plt.show()

# %% [markdown]
# ## Pie Chart to show Order Quantity against Age Group

# %%
Age_Group= df['Age_Group'].value_counts()
plt.figure(figsize =(10, 10))

# %%
##Revenue per Country Break down
plt.pie(Age_Group, labels = Age_Group.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'larger'}, radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d6b4146e50>,
# ...
#  [Text(-1.0847805750587625, -1.2432823910822435, 'Adults (35-64)'),
#   Text(1.556863130644511, 0.5465136708626536, 'Young Adults (25-34)'),
#   Text(-0.5449557629978907, 1.5574091358327737, 'Youth (<25)'),
#   Text(-1.242196504911781, 1.0860238686073875, 'Seniors (64+)')],
#  [Text(-0.5916984954865976, -0.6781540314994053, '49.39%'),
#   Text(0.8491980712606422, 0.2980983659250837, '34.20%'),
#   Text(-0.29724859799884945, 0.849495892272422, '15.77%'),
#   Text(-0.6775617299518804, 0.5923766556040295, '0.65%')])

# %% [markdown]
# ## Pie Chart to show the country by revenue

# %%
Country= df['Country'].value_counts()

# %%
plt.figure(figsize =(100, 100))

# %%
plt.pie(Country, labels = Country.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'larger'}, radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d6b0f6c490>,
# ...
#  [Text(-1.5251479758747917, -0.629621832281113, 'United States'),
#   Text(0.8981781764603916, -1.384115588861814, 'Australia'),
#   Text(1.6466098165880483, 0.10571713161013395, 'Canada'),
#   Text(1.1053615639349115, 1.2250207398143782, 'United Kingdom'),
#   Text(0.07770619478461938, 1.648169210758439, 'Germany'),
#   Text(-0.8862197359377975, 1.3918026367392544, 'France')],
#  [Text(-0.8318988959317044, -0.3434300903351525, '34.68%'),
#   Text(0.48991536897839527, -0.7549721393791712, '21.18%'),
#   Text(0.8981508090480261, 0.05766388996916396, '12.54%'),
#   Text(0.6029244894190425, 0.6681931308078426, '12.05%'),
#   Text(0.042385197155246926, 0.899001387686421, '9.82%'),
#   Text(-0.4833925832387985, 0.7591650745850477, '9.73%')])

# %%
num_df = df[numerical]

# %% [markdown]
# ## Frequency Distribution of profit

# %%
Frequency = pd.crosstab(index=df["Revenue"], columns='count')


Frequency.plot(kind="density", figsize=(20,20), xlim=(0,1000))

plt.title("Sub category break down of Product ")

plt.ylabel("Total number of products per sale")

plt.xlabel("Sub category of all products")

#df["Revenue"].plot(kind ="density", figsize=(8, 8), xlim=(1, 10000)) 
# plt.plot(kind = "bar", figsize=(10,10))

# rev_Profit_corr = df[corelation].corr()
# rev_Profit_corr



# df["Revenue"].plot(kind ="density", figsize=(8, 8), xlim=(0, 100))
# Out:
# Text(0.5, 0, 'Sub category of all products')

# %% [markdown]
# ### Checking for Correlation between our Mean and Median

# %%
skewed_df = df[numerical]

# %%
skewed_df = pd.DataFrame(np.random.exponential(size=1000))

skewed_df.plot(kind="density", figsize=(10,10), xlim=(-1,5));

plt.vlines(skewed_df.mean(), ymin=0, ymax=0.8, linewidth=5.0, color='black');  # Plot black at mean

plt.vlines(skewed_df.median(), ymin=0, ymax=0.8, linewidth=2.0, color='red')  # Plot red line at median

plt.title("Skewed Relation between Mean and median");

plt.xlabel("Numerical Values")
# Out:
# Text(0.5, 0, 'Numerical Values')

# %% [markdown]
# ### The mean is also influenced heavily by the outliers, whiles the median resist the influence of the outliers

# %%
norm_data = df[numerical]

# %%
norm_data = np.random.normal(size=50)

outliers = np.random.normal(15, size=3);

combine_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0));

combine_data.plot(kind="density", xlim=(-5, 20));

plt.vlines(skewed_df.mean(), ymin=0, ymax=0.2, linewidth=5.0, color='black');  # Plot black at mean

plt.vlines(skewed_df.median(), ymin=0, ymax=0.2, linewidth=2.0, color='red')  # Plot red line at median

plt.title("Normal Relationship between mean and median")

plt.xlabel("Numerical Values")
# Out:
# Text(0.5, 0, 'Numerical Values')

# %% [markdown]
# #### Since the the median tends to resist the effect of skewness and outliers, it is as known a "robust" statistics,
# #### the median generally gives sense of typical value in a distribution with significant skew or outliers

# %%
# ## Step 3: Feature Understanding
# - (Univariate Analysis)
#   - Histogram
#   - KDE
#   - Boxplot
