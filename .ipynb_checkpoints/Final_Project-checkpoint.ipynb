# %% [markdown]
# ## Data Analytics Final Project

# %% [markdown]
# ## Step 0 : Imports and Reading Data

# %%
## Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp


## Reading and making copy of DataFrame
data_df = pd.read_csv('Datasets/sales_data.csv')
df = data_df.copy()

# %% [markdown]
# ## Step 1: Data Understanding
# - Dataframe Shape
# - head and tail
# - Dtypes
# - describe
# - Columns

# %%
df.shape
# Out:
# (113036, 18)

# %%
## First Five Rows from top
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %%
## Last Five Rows from Bottom
df.tail()
# Out:
#            Date  Day      Month  Year  Age       Age_Group Gender  Country  \
# 995  2015-09-17   17  September  2015   18     Youth (<25)      F  Germany
# 996  2013-10-27   27    October  2013   19     Youth (<25)      F  Germany
# 997  2015-10-27   27    October  2015   19     Youth (<25)      F  Germany
# 998  2013-09-19   19  September  2013   52  Adults (35-64)      F  Germany
# 999  2015-09-19   19  September  2015   52  Adults (35-64)      F  Germany
#
#                    State Product_Category Sub_Category  \
# 995             Saarland      Accessories  Bike Stands
# 996  Nordrhein-Westfalen      Accessories  Bike Stands
# 997  Nordrhein-Westfalen      Accessories  Bike Stands
# 998              Hamburg      Accessories  Bike Stands
# 999              Hamburg      Accessories  Bike Stands
#
#                     Product  Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 995  All-Purpose Bike Stand         3         59         159     214   177
# 996  All-Purpose Bike Stand         9         59         159     714   531
# 997  All-Purpose Bike Stand         7         59         159     555   413
# 998  All-Purpose Bike Stand         5         59         159     444   295
# 999  All-Purpose Bike Stand         2         59         159     178   118
#
#      Revenue
# 995      391
# 996     1245
# 997      968
# 998      739
# 999      296

# %%
## Renaming some columns in the Data
df.rename(columns={'Customer_Age':'Age', 'Customer_Gender':'Gender', 'Order_Quantity': 'Quantity'} , inplace=True)

# %%
df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Age                  int64
# Age_Group           object
# Gender              object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Quantity             int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
df.describe()
# Out:
#                Day         Year          Age    Quantity    Unit_Cost  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     16.048000  2014.514000    37.276000     6.89800    50.656000
# std       8.835823     1.118506    11.410786     5.60616     6.873202
# min       1.000000  2013.000000    17.000000     1.00000    45.000000
# 25%       9.000000  2014.000000    29.000000     3.00000    45.000000
# 50%      16.500000  2014.500000    35.500000     6.00000    45.000000
# 75%      24.000000  2016.000000    45.000000     9.00000    59.000000
# max      31.000000  2016.000000    87.000000    30.00000    59.000000
#
#         Unit_Price       Profit         Cost      Revenue
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    135.756000   485.472000   340.440000   825.912000
# std      19.146777   383.539748   256.758672   636.258197
# min     120.000000    49.000000    45.000000    94.000000
# 25%     120.000000   217.000000   177.000000   373.500000
# 50%     120.000000   407.000000   295.000000   706.000000
# 75%     159.000000   632.000000   450.000000  1068.000000
# max     159.000000  2214.000000  1350.000000  3564.000000

# %%
#Display our Columns
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Age', 'Age_Group', 'Gender', 'Country',
#        'State', 'Product_Category', 'Sub_Category', 'Product', 'Quantity',
#        'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# ## Step 2 : Data Preparation
# - Dropping some Columns to make our analysis fare and easier in graph generating
# - Identifying Duplicated Columns

# %%
## Dropping some columns by commenting them out to reduce the number of columns
## to Aid in making the analysis easier to analyse

Dat_df = df[[#'Date',
         #, 'Month', 
                'Age','Day',
                #'Age_Group',
         'Gender', 'Country', 'State',
                #'Product_Category', 
               #'Sub_Category',,'Unit_Cost'
         'Product', 
           'Year','Quantity','Cost','Unit_Price','Profit','Revenue']].copy()

# %%
##Display the data types after Dropping some columns
Dat_df.dtypes
# Out:
# Age            int64
# Day            int64
# Gender        object
# Country       object
# State         object
# Product       object
# Year           int64
# Quantity       int64
# Cost           int64
# Unit_Price     int64
# Profit         int64
# Revenue        int64
# dtype: object

# %%
## Dropping some rows in our dataset data[1001:113036] 
#df = df.drop[1000:113036].copy() 
df.drop(df.index[1000 : 113036], axis=0, inplace=True)

# %%
df.shape
# Out:
# (1000, 18)

# %%
## Checking for missing and unique values 

##fortunately the Dataframe has no missing values

# %% [markdown]
# ## Step 3: Data Preprocessing

# %% [markdown]
# ### Grouping Data into Numerical and Categorical

# %%
numerical = ['Day', 'Quantity', 'Unit_Price', 'Profit', 'Cost', 'Revenue', 'Age', 'Year']

categorical = ['Date', 'Month', 'Age_Group', 'Gender', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product']

# %% [markdown]
# ## Step 4: Descriptive Analysis
# - Total Revenue, Highest Revenue, Lowest Revenue

# %%
## Total Revenue

df['Revenue'].sum()
# Out:
# 825912

# %%
## Minimum Revenue

df['Revenue'].min()
# Out:
# 94

# %%
## Highest revenue
df['Revenue'].max()
# Out:
# 3564

# %%
## renaming the Group Data

cat_cols = numerical =['Date','Month','Gender', 'Country','State','Product_Category', 'Sub_Category','Product','Gender', 'Age_Group']

num_cols = categorical=['Day', 'Year', 'Age','Quantity', 'Unit_Price','Profit','Cost', 'Revenue']

# %%
## Assigning renamed group to a variable
cat_df = df[cat_cols]

num_df = df[num_cols]

# %%
## Finding the Corelationship of our numerical values
numerical_df = num_df.corr()

numerical_df
# Out:
#                  Day      Year       Age  Quantity  Unit_Price    Profit  \
# Day         1.000000  0.003781  0.002728  0.041222   -0.022474  0.038498
# Year        0.003781  1.000000  0.063382 -0.007594   -0.021248 -0.008131
# Age         0.002728  0.063382  1.000000  0.087067   -0.032432  0.085836
# Quantity    0.041222 -0.007594  0.087067  1.000000   -0.233417  0.959090
# Unit_Price -0.022474 -0.021248 -0.032432 -0.233417    1.000000 -0.084976
# Profit      0.038498 -0.008131  0.085836  0.959090   -0.084976  1.000000
# Cost        0.034727 -0.016076  0.080013  0.984423   -0.087215  0.973813
# Revenue     0.037221 -0.011389  0.084031  0.975403   -0.086419  0.995782
#
#                 Cost   Revenue
# Day         0.034727  0.037221
# Year       -0.016076 -0.011389
# Age         0.080013  0.084031
# Quantity    0.984423  0.975403
# Unit_Price -0.087215 -0.086419
# Profit      0.973813  0.995782
# Cost        1.000000  0.990565
# Revenue     0.990565  1.000000

# %%
#  The above correlationship analysis
sns.heatmap(numerical_df, xticklabels= numerical_df.columns, yticklabels= numerical_df.columns, annot = True)
plt.title('correlation between numerical values')
# Out:
# Text(0.5, 1.0, 'correlation between numerical values')

# %%
# Out:
# array([[<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Unit_Cost'}>,
#         <Axes: title={'center': 'Unit_Price'}>],
#        [<Axes: title={'center': 'Profit'}>,
#         <Axes: title={'center': 'Cost'}>,
#         <Axes: title={'center': 'Revenue'}>]], dtype=object)

# %%
## Correlationship between Revenue and Year
plt.scatter(df['Year'], df['Revenue'], c = 'red')

plt.title('Relation between Revenue and Year')

plt.ylabel('Revenue')

plt.xlabel('Year')

plt.savefig('Revenue_year_rel.png')

plt.show()

# %%
## CORrELATIONSHIP between Revenue and Day
plt.scatter(df['Day'], df['Revenue'], c = 'Green')

plt.title('Relation between Revenue and Day')

plt.ylabel('Revenue')

plt.xlabel('Day')

plt.savefig('Revenue_Day_rel.png')

plt.show()

# %%
## CORELATION between Revenue and Customer_Age
plt.scatter(df['Age'], df['Revenue'], c = 'magenta')

plt.title('Relation between Revenue and Customer_Age')

plt.ylabel('Revenue')

plt.xlabel('Age')

plt.savefig('Revenue_CAge_rel.png')

plt.show()

# %%
## CORELATION between Revenue and Order Quantity
plt.scatter(df['Quantity'], df['Revenue'], c = 'blue')

plt.title('Relation between Revenue and Order Quantity')

plt.ylabel('Revenue')

plt.xlabel('Quantity')

plt.savefig('Revenue_CAge_rel.png')

plt.show()

# %%
## CORELATION between Revenue and Unit Price
plt.scatter(df['Unit_Price'], df['Revenue'], c = 'cyan')

plt.title('Relation between Revenue and Unit Price')

plt.ylabel('Revenue')

plt.xlabel('Unit Price')

plt.savefig('Revenue_numitprice_rel.png')

plt.show()

# %%
## CORELATION between Revenue and Profit
plt.scatter(df['Revenue'], df['Profit'], c = 'forestgreen')

plt.title('Relation between Revenue and Proft')

plt.ylabel('Revenue')

plt.xlabel('Profit')

plt.savefig('Revenue_Profit_rel.png')

plt.show()

# %%
## CORELATION between Revenue and Cost
plt.scatter(df['Cost'], df['Revenue'], c = 'darkviolet')

plt.title('Relation between Revenue and Cost')

plt.ylabel('Revenue')

plt.xlabel('Cost')

plt.savefig('Revenue_Cost_rel.png')

plt.show()

# %%
numerical_df = num_df.corr()

numerical_df
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Price  \
# Day             1.000000  0.003781      0.002728        0.041222   -0.022474
# Year            0.003781  1.000000      0.063382       -0.007594   -0.021248
# Customer_Age    0.002728  0.063382      1.000000        0.087067   -0.032432
# Order_Quantity  0.041222 -0.007594      0.087067        1.000000   -0.233417
# Unit_Price     -0.022474 -0.021248     -0.032432       -0.233417    1.000000
# Profit          0.038498 -0.008131      0.085836        0.959090   -0.084976
# Cost            0.034727 -0.016076      0.080013        0.984423   -0.087215
# Revenue         0.037221 -0.011389      0.084031        0.975403   -0.086419
#
#                   Profit      Cost   Revenue
# Day             0.038498  0.034727  0.037221
# Year           -0.008131 -0.016076 -0.011389
# Customer_Age    0.085836  0.080013  0.084031
# Order_Quantity  0.959090  0.984423  0.975403
# Unit_Price     -0.084976 -0.087215 -0.086419
# Profit          1.000000  0.973813  0.995782
# Cost            0.973813  1.000000  0.990565
# Revenue         0.995782  0.990565  1.000000

# %% [markdown]
# ### Histogram Distribution of Data columns

# %%
df.hist(figsize = (15, 15), color='indigo')
# Out:
# array([[<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Unit_Cost'}>,
#         <Axes: title={'center': 'Unit_Price'}>],
#        [<Axes: title={'center': 'Profit'}>,
#         <Axes: title={'center': 'Cost'}>,
#         <Axes: title={'center': 'Revenue'}>]], dtype=object)

# %% [markdown]
# ## Country by Distribution Count

# %%
# Value count of the countries 

country= pd.crosstab(index=df["Country"], columns='count')
country
# Out:
# col_0           count
# Country
# Australia         196
# Canada            148
# France             84
# Germany            84
# United Kingdom    110
# United States     378

# %%
country.plot(kind="bar", figsize=(8,8))

plt.title('Countries per Distribution')

plt.ylabel('Customers')

plt.xlabel('Country')
# Out:
# Text(0.5, 0, 'Country')

# %% [markdown]
# ## Sales Distribution by Sales

# %%
State= pd.crosstab(index=df["State"], columns='count')
State
# Out:
# col_0                count
# State
# Alberta                  4
# Bayern                   8
# British Columbia       144
# California             210
# England                110
# Essonne                  4
# Hamburg                  8
# Hauts de Seine           6
# Hessen                  16
# Kentucky                 2
# Loir et Cher             2
# Loiret                   6
# Moselle                  4
# New South Wales         80
# Nord                    16
# Nordrhein-Westfalen     26
# Oregon                  54
# Queensland              58
# Saarland                26
# Seine (Paris)           18
# Seine Saint Denis       14
# Seine et Marne           2
# South Australia         14
# Tasmania                 2
# Val d'Oise               2
# Val de Marne             2
# Victoria                42
# Washington             112
# Yveline                  8

# %%
State = pd.crosstab(index=df["State"], columns='count')

State.plot(kind="bar", figsize=(15,15))

plt.title("Sales Distribution by State ")

plt.ylabel("Products per sale")

plt.xlabel("States")
# Out:
# Text(0.5, 0, 'States')

# %%
sns.barplot(data = df, y='Revenue', x='Age_Group', hue='Country', errorbar=None)
plt.title('Order Quantity Distribution against Age Group.')
plt.xlabel('Age Group')
plt.ylabel('Quantity')

plt.show()

# %% [markdown]
# ## Pie Chart to show the country by revenue

# %%
Country= df['Country'].value_counts()

# %%
plt.figure(figsize =(100, 100))

# %%
plt.pie(Country, labels = Country.index, autopct = '%1.2f%%', startangle = 140, textprops={'size': 'larger'}, radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bcc9eae1d0>,
#   <matplotlib.patches.Wedge at 0x1bccbacbd90>,
#   <matplotlib.patches.Wedge at 0x1bccbc79590>,
#   <matplotlib.patches.Wedge at 0x1bccbcb28d0>,
#   <matplotlib.patches.Wedge at 0x1bccbcbc050>,
#   <matplotlib.patches.Wedge at 0x1bccbcbd810>],
#  [Text(-1.4563224023102221, -0.7756449319949069, 'United States'),
#   Text(1.090300157434269, -1.2384448177851157, 'Australia'),
#   Text(1.6058775723329803, 0.3790214013455364, 'Canada'),
#   Text(0.8319733589113293, 1.42489309425718, 'United Kingdom'),
#   Text(-0.13347626321804998, 1.6445923772039521, 'Germany'),
#   Text(-0.9435681381951082, 1.3535801300931607, 'France')],
#  [Text(-0.7943576739873938, -0.42307905381540367, '37.80%'),
#   Text(0.5947091767823284, -0.6755153551555176, '19.60%'),
#   Text(0.8759332212725345, 0.20673894618847435, '14.80%'),
#   Text(0.4538036503152704, 0.7772144150493707, '11.00%'),
#   Text(-0.0728052344825727, 0.8970503875657919, '8.40%'),
#   Text(-0.5146735299246044, 0.7383164345962693, '8.40%')])

# %% [markdown]
# ### Checking for Correlation between our Mean and Median

# %%
skewed_df = df[numerical]

# %%
skewed_df = pd.DataFrame(np.random.exponential(size=1000))

skewed_df.plot(kind="density", figsize=(10,10), xlim=(-1,5));

plt.vlines(skewed_df.mean(), ymin=0, ymax=0.8, linewidth=5.0, color='black');  # Plot black at mean

plt.vlines(skewed_df.median(), ymin=0, ymax=0.8, linewidth=2.0, color='red')  # Plot red line at median

plt.title("Skewed Relation between Mean and median");

plt.xlabel("Numerical Values")
# Out:
# Text(0.5, 0, 'Numerical Values')

# %% [markdown]
# ### The mean is also influenced heavily by the outliers, whiles the median resist the influence of the outliers

# %%
norm_data = df[numerical]

# %%
norm_data = np.random.normal(size=50)

outliers = np.random.normal(15, size=3);

combine_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0));

combine_data.plot(kind="density", xlim=(-5, 20));

plt.vlines(skewed_df.mean(), ymin=0, ymax=0.2, linewidth=5.0, color='black');  # Plot black at mean

plt.vlines(skewed_df.median(), ymin=0, ymax=0.2, linewidth=2.0, color='red')  # Plot red line at median

plt.title("Normal Relationship between mean and median")

plt.xlabel("Numerical Values")
# Out:
# Text(0.5, 0, 'Numerical Values')

# %% [markdown]
# #### Since the the median tends to resist the effect of skewness and outliers, it is as known a "robust" statistics,
# #### the median generally gives sense of typical value in a distribution with significant skew or outliers
