# %% [markdown]
# ### My own tutorial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy as sp

# %%
## intersection, differentiation, neither

arr1 = np.array([1,2,3,4,5])
arr2 = np.array([3,4,5,6,7])
print(np.intersect1d(arr1, arr2))
print(np.union1d(arr1, arr2))
print(np.setdiff1d(arr1, arr2))
print(np.setxor1d(arr1, arr2))
# Out:
# [3 4 5]
# [1 2 3 4 5 6 7]
# [1 2]
# [1 2 6 7]

# %%
data_df = pd.read_csv('Datasets/used_device_data.csv')
data_df
# Out:
#      brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0         Honor  Android        14.50  yes   no            13.0
# 1         Honor  Android        17.30  yes  yes            13.0
# 2         Honor  Android        16.69  yes  yes            13.0
# 3         Honor  Android        25.50  yes  yes            13.0
# 4         Honor  Android        15.32  yes   no            13.0
# ...         ...      ...          ...  ...  ...             ...
# 3449       Asus  Android        15.34  yes   no             NaN
# 3450       Asus  Android        15.24  yes   no            13.0
# 3451    Alcatel  Android        15.80  yes   no            13.0
# 3452    Alcatel  Android        15.80  yes   no            13.0
# 3453    Alcatel  Android        12.83  yes   no            13.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0                  5.0        64.0  3.0   3020.0   146.0          2020
# 1                 16.0       128.0  8.0   4300.0   213.0          2020
# 2                  8.0       128.0  8.0   4200.0   213.0          2020
# 3                  8.0        64.0  6.0   7250.0   480.0          2020
# 4                  8.0        64.0  3.0   5000.0   185.0          2020
# ...                ...         ...  ...      ...     ...           ...
# 3449               8.0        64.0  6.0   5000.0   190.0          2019
# 3450               8.0       128.0  8.0   4000.0   200.0          2018
# 3451               5.0        32.0  3.0   4000.0   165.0          2020
# 3452               5.0        32.0  2.0   4000.0   160.0          2020
# 3453               5.0        16.0  2.0   4000.0   168.0          2020
#
#       days_used  used_price
# 0           127       74.26
# 1           325      174.53
# 2           162      165.85
# 3           345      169.93
# 4           293       80.64
# ...         ...         ...
# 3449        232       89.33
# 3450        541      154.12
# 3451        201       78.05
# 3452        149       77.46
# 3453        176       62.31
#
# [3454 rows x 14 columns]

# %%
data_df.dtypes
# Out:
# brand_name           object
# os                   object
# screen_size         float64
# 4g                   object
# 5g                   object
# main_camera_mp      float64
# selfie_camera_mp    float64
# int_memory          float64
# ram                 float64
# battery             float64
# weight              float64
# release_year          int64
# days_used             int64
# used_price          float64
# dtype: object

# %%
data_df.columns
# Out:
# Index(['brand_name', 'os', 'screen_size', '4g', '5g', 'main_camera_mp',
#        'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'used_price'],
#       dtype='object')

# %%
data_df.columns.values
# Out:
# array(['brand_name', 'os', 'screen_size', '4g', '5g', 'main_camera_mp',
#        'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight',
#        'release_year', 'days_used', 'used_price'], dtype=object)

# %%
# Analytical summary of the dataset

data_df.describe(include='all')
# Out:
#        brand_name       os  screen_size    4g    5g  main_camera_mp  \
# count        3454     3454  3454.000000  3454  3454     3275.000000
# unique         34        4          NaN     2     2             NaN
# top        Others  Android          NaN   yes    no             NaN
# freq          502     3214          NaN  2335  3302             NaN
# mean          NaN      NaN    13.713115   NaN   NaN        9.460208
# std           NaN      NaN     3.805280   NaN   NaN        4.815461
# min           NaN      NaN     5.080000   NaN   NaN        0.080000
# 25%           NaN      NaN    12.700000   NaN   NaN        5.000000
# 50%           NaN      NaN    12.830000   NaN   NaN        8.000000
# 75%           NaN      NaN    15.340000   NaN   NaN       13.000000
# max           NaN      NaN    30.710000   NaN   NaN       48.000000
#
#         selfie_camera_mp   int_memory          ram      battery       weight  \
# count        3452.000000  3450.000000  3450.000000  3448.000000  3447.000000
# unique               NaN          NaN          NaN          NaN          NaN
# top                  NaN          NaN          NaN          NaN          NaN
# freq                 NaN          NaN          NaN          NaN          NaN
# mean            6.554229    54.573099     4.036122  3133.402697   182.751871
# std             6.970372    84.972371     1.365105  1299.682844    88.413228
# min             0.000000     0.010000     0.020000   500.000000    69.000000
# 25%             2.000000    16.000000     4.000000  2100.000000   142.000000
# 50%             5.000000    32.000000     4.000000  3000.000000   160.000000
# 75%             8.000000    64.000000     4.000000  4000.000000   185.000000
# max            32.000000  1024.000000    12.000000  9720.000000   855.000000
#
#         release_year    days_used   used_price
# count    3454.000000  3454.000000  3454.000000
# unique           NaN          NaN          NaN
# top              NaN          NaN          NaN
# freq             NaN          NaN          NaN
# mean     2015.965258   674.869716    92.302936
# std         2.298455   248.580166    54.701648
# min      2013.000000    91.000000     4.650000
# 25%      2014.000000   533.500000    56.482500
# 50%      2015.500000   690.500000    81.870000
# 75%      2018.000000   868.750000   116.245000
# max      2020.000000  1094.000000   749.520000

# %%
data_df.isnull().sum()
# Out:
# brand_name            0
# os                    0
# screen_size           0
# 4g                    0
# 5g                    0
# main_camera_mp      179
# selfie_camera_mp      2
# int_memory            4
# ram                   4
# battery               6
# weight                7
# release_year          0
# days_used             0
# used_price            0
# dtype: int64

# %%
data_df.boxplot()
# Out:
# <Axes: >

# %%
data_df.hist(figsize=(20, 30))
# Out:
# array([[<Axes: title={'center': 'screen_size'}>,
#         <Axes: title={'center': 'main_camera_mp'}>,
#         <Axes: title={'center': 'selfie_camera_mp'}>],
#        [<Axes: title={'center': 'int_memory'}>,
#         <Axes: title={'center': 'ram'}>,
#         <Axes: title={'center': 'battery'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'days_used'}>],
#        [<Axes: title={'center': 'used_price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# realationship between categorical and continues variables 

sns.boxplot(y='screen_size', x='used_price', data = data_df)

plt.title('relationship between price and screen size')
# Out:
# Text(0.5, 1.0, 'relationship between price and screen size')

# %%
sns.pairplot(data_df) ## figsize(20,30)

# %%
## os, int_memory, days_used
data_df = data_df.drop(['os', 'int_memory', 'days_used'], axis = 1)
data_df.head(5)
# Out:
#   brand_name  screen_size   4g   5g  main_camera_mp  selfie_camera_mp  ram  \
# 0      Honor        14.50  yes   no            13.0               5.0  3.0
# 1      Honor        17.30  yes  yes            13.0              16.0  8.0
# 2      Honor        16.69  yes  yes            13.0               8.0  8.0
# 3      Honor        25.50  yes  yes            13.0               8.0  6.0
# 4      Honor        15.32  yes   no            13.0               8.0  3.0
#
#    battery  weight  release_year  used_price
# 0   3020.0   146.0          2020       74.26
# 1   4300.0   213.0          2020      174.53
# 2   4200.0   213.0          2020      165.85
# 3   7250.0   480.0          2020      169.93
# 4   5000.0   185.0          2020       80.64

# %%
# renaming column headings

data_df = data_df.rename(columns={"brand_name": "brand", "screen_size": "size", "release_year": "year"})
data_df.head(5)
# Out:
#    brand   size   4g   5g  main_camera_mp  selfie_camera_mp  ram  battery  \
# 0  Honor  14.50  yes   no            13.0               5.0  3.0   3020.0
# 1  Honor  17.30  yes  yes            13.0              16.0  8.0   4300.0
# 2  Honor  16.69  yes  yes            13.0               8.0  8.0   4200.0
# 3  Honor  25.50  yes  yes            13.0               8.0  6.0   7250.0
# 4  Honor  15.32  yes   no            13.0               8.0  3.0   5000.0
#
#    weight  year  used_price
# 0   146.0  2020       74.26
# 1   213.0  2020      174.53
# 2   213.0  2020      165.85
# 3   480.0  2020      169.93
# 4   185.0  2020       80.64

# %%
## Total number Rows and Columns

data_df.shape
# Out:
# (3454, 11)

# %%
# checking for rows with duplicate data

duplicate_data_df = data_df[data_df.duplicated()]
print("Number of rows with duplicate: ", duplicate_data_df.shape)
# Out:
# Number of rows with duplicate:  (0, 11)

# %%
## count the rows before removing data

data_df.count()
# Out:
# brand               3454
# size                3454
# 4g                  3454
# 5g                  3454
# main_camera_mp      3275
# selfie_camera_mp    3452
# ram                 3450
# battery             3448
# weight              3447
# year                3454
# used_price          3454
# dtype: int64

# %%
## drop the duplicate

data_df = data_df.drop_duplicates()
data_df.head()
# Out:
#    brand   size   4g   5g  main_camera_mp  selfie_camera_mp  ram  battery  \
# 0  Honor  14.50  yes   no            13.0               5.0  3.0   3020.0
# 1  Honor  17.30  yes  yes            13.0              16.0  8.0   4300.0
# 2  Honor  16.69  yes  yes            13.0               8.0  8.0   4200.0
# 3  Honor  25.50  yes  yes            13.0               8.0  6.0   7250.0
# 4  Honor  15.32  yes   no            13.0               8.0  3.0   5000.0
#
#    weight  year  used_price
# 0   146.0  2020       74.26
# 1   213.0  2020      174.53
# 2   213.0  2020      165.85
# 3   480.0  2020      169.93
# 4   185.0  2020       80.64

# %%
# 
data_df.hist(column = 'used_price', figsize = (8,8), color='green', bins= 50, range= (10,20))
# Out:
# array([[<Axes: title={'center': 'used_price'}>]], dtype=object)

# %%
data_df.boxplot(column = "main_camera_mp", by = "brand", figsize=(25,25), color='blue')
# Out:
# <Axes: title={'center': 'main_camera_mp'}, xlabel='brand'>

# %%
country= pd.crosstab(index=data_df["main_camera_mp"], columns='count')
country
# Out:
# col_0           count
# main_camera_mp
# 0.08                1
# 0.30               69
# 1.00                1
# 1.20                1
# 1.30               26
# 2.00              171
# 3.00                5
# 3.15              122
# 4.00               10
# 5.00              546
# 6.50                4
# 6.70                4
# 8.00              755
# 8.10                7
# 10.00               6
# 10.50              30
# 12.00             189
# 12.20              12
# 12.30               9
# 12.50               4
# 12.60               1
# 13.00            1035
# 13.10               6
# 14.50              13
# 16.00             154
# 16.30               1
# 18.00               1
# 19.00               8
# 20.00              13
# 20.10               1
# 20.20               1
# 20.70              16
# 21.00              19
# 21.20               2
# 21.50               1
# 22.50               1
# 22.60               1
# 23.00              19
# 24.00               5
# 41.00               1
# 48.00               4

# %%
data_df["main_camera_mp"].plot(kind ="density", figsize=(8, 8), xlim=(0, 50)) 

plt.title('Relationship Between Gender')

plt.ylabel('Customers')

plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
data_team= pd.crosstab(index=data_df["brand"], columns='count')
data_team
# Out:
# col_0       count
# brand
# Acer           51
# Alcatel       121
# Apple          39
# Asus          122
# BlackBerry     22
# Celkon         33
# Coolpad        22
# Gionee         56
# Google         15
# HTC           110
# Honor         116
# Huawei        251
# Infinix        10
# Karbonn        29
# LG            201
# Lava           36
# Lenovo        171
# Meizu          62
# Micromax      117
# Microsoft      22
# Motorola      106
# Nokia         106
# OnePlus        22
# Oppo          129
# Others        502
# Panasonic      47
# Realme         41
# Samsung       341
# Sony           86
# Spice          30
# Vivo          117
# XOLO           49
# Xiaomi        132
# ZTE           140

# %%
 data_team.plot(kind="bar", figsize=(8,8))
# Out:
# <Axes: xlabel='brand'>

# %%
x=data_df['used_price'][data_df['used_price'] < 500]
x.sum()
# Out:
# 317399.38

# %%
pd.set_option('display.float_format', lambda x: '%:2%f' % x)

# %% [markdown]
# ## My other tutorials from other videos

# %%
# Checking for duplicate copies in a dataset
print(data_df.duplicated().sum())
# Out:
# 0

# %%
# Replacing null values
df.raplace(np.nan,"0", inplace = True)

# %%
# to filter data greater than a particlure year
df2 = df[df['coulumn_name'] > year] #(example 2018)

# %%
# Filtering 
df2 = df[df['coulumn_name'] == year] #(example 2018)

# %%
data_df.boxplot()

# %%
# data_team.plot(kind="bar")

# %%
# customer_age= pd.crosstab(index=df["Customer_Age"], columns='count')
# customer_age

# %%
# customer_age.plot(kind="bar", figsize=(50,50))

# %%
#Value count of the countries

# %%
# country= pd.crosstab(index=df["Country"], columns='count')
# country

# %%
# country.plot(kind="bar", figsize=(8,8))

# plt.title('Countries per Customers')

# plt.ylabel('Customers')

# plt.xlabel('Country')

# %%
# gender= pd.crosstab(index=df["Customer_Gender"], columns='count')
# gender

# %%
# gender.plot(kind="bar")

# plt.title('Relationship Between Gender')

# plt.ylabel('Customers')

# plt.xlabel('Gender')

# %%
# customer_age= pd.crosstab(index=df["Revenue"], columns='count')
# customer_age

# %%
# df["Year"].plot(kind ="density", figsize=(20, 20), xlim=(0, 5)) 

# plt.title('Relationship Between Gender')

# plt.ylabel('Customers')

# plt.xlabel('Gender')

# %%
# customer_age.mean()

# %%
# customer_age.median()

# %%
# unit_cost= pd.crosstab(index=df["Unit_Cost"], columns='count')
# unit_cost

# %%
# customer_age.median()

# %%
# unit_cost= pd.crosstab(index=df["Unit_Cost"], columns='count')
# unit_cost

# %%
# unit_cost.mean()

# %%
# unit_cost.median()

# %%
# norm_data = pd.DataFrame(np.random.normal(size=1000))
# norm_data.plot(kind="density", figsize=(10,10));
# plt.vlines(norm_data.mean(), ymin=0, ymax=0.4, linewidth= 5.0);
# plt.vlines(norm_data.median(), ymin=0, ymax=0.4, linewidth=2.0, color="red");

# %%
# num_df = device_data[numerical]

# cat_df = device_data[categorical

# %%
# corr_df = df[numerical]
# corr_df
