# %% [markdown]
# ## Step 0 : Imports and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
# Read dataset
data_df = pd.read_csv('Datasets/sales_data.csv')

# %% [markdown]
# ## Step 1: Data Understanding
# - Dataframe Shape
# - head and tail
# - Dtypes
# - describe

# %%
## Dataframe shape
data_df.shape
# Out:
# (113036, 18)

# %%
data_df.head(5)
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data_df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
data_df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
data_df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# ## Step 2: Data Preparation
# - Dropping Irrelevant Columns and Rows
# - Identifying Duplicated Columns
# - Renaming Columns
# - Feature Creation

# %%
# ## Data Cleaning
# ## Example of droping a single column
# data_df(['Column_name'], axis=1)

# %%
# # Dropping some columns by commenting out the unwanted columns
df = data_df[[#'Date',
         #'Day', 'Month', 
                'Customer_Age',
                #'Age_Group',
         'Customer_Gender', 'Country', 'State',
                #'Product_Category', 
               #'Sub_Category','Cost',
         'Product', 
           'Year','Order_Quantity', 'Unit_Cost','Unit_Price','Profit','Revenue']].copy()

# %%
df.dtypes
# Out:
# Customer_Age        int64
# Customer_Gender    object
# Country            object
# State              object
# Product            object
# Year                int64
# Order_Quantity      int64
# Unit_Cost           int64
# Unit_Price          int64
# Profit              int64
# Revenue             int64
# dtype: object

# %%
df = df.reset_index(drop=True).copy()

# %%
df.head(20)
# Out:
#     Customer_Age Customer_Gender    Country             State  \
# 0             19               M     Canada  British Columbia
# 1             19               M     Canada  British Columbia
# 2             49               M  Australia   New South Wales
# 3             49               M  Australia   New South Wales
# 4             47               F  Australia   New South Wales
# 5             47               F  Australia   New South Wales
# 6             47               F  Australia          Victoria
# 7             47               F  Australia          Victoria
# 8             35               M  Australia          Victoria
# 9             35               M  Australia          Victoria
# 10            32               F  Australia          Victoria
# 11            32               F  Australia          Victoria
# 12            34               M  Australia          Victoria
# 13            34               M  Australia          Victoria
# ...

# %%
# # Option 1
# df['year'] = pd.to_datetime(df['year'])

# # Option 2
# df['year'] = pd.to_numeric(df['year'])

# %%
# # Renaming columns
# df = df.rename(columns={'Old_name': 'new_name', 
                        
#                         '' }) # repeat to all columns you want to rename

# %%
# df.isna().sum() or df.isnull().sum()

# %%
## Find duplicated values and location
# df.loc[df.duplicated()]

# # or

# df.loc[df.duplicated(subset=['name_of_column_look_for']).head(5)

# %%
# # fetching the duplicate names 
# df.query('column_name' == 'duplicate_row_name')

# %%
# df = df.loc[~df.duplicated(subset=['column_names', ])] \ .reset_index(drop=True).copy()

# %% [markdown]
# ## Step 3: Feature Understanding
# - (Univariate Analysis)
#   - Histogram
#   - KDE
#   - Boxplot

# %%
# # Potential distribution on a particular column

# df['column_name'].value_counts()

# %%
# # ploting a bar graph
# ax = df['column_name'].value_counts() \
#         .head(10) \
#         .plot(kind='bar', title='Top 10 Years of the name of the dataset')
# ax.set_xlabel('Year Introduced')
# ax.set_ylabel('Counts')

# %%
# ## Distribution of the Columns

# ax = df['any_column_of_choice'].plot(kind='hist',
#                                      bins=20, 
#                                      title='Column_name')
# ax.set_xlabel('column_name')

# %%
# ## Distribution of the Columns

# ax = df['any_column_of_choice'].plot(kind='kde',
#                                      bins=20, 
#                                      title='Column_name')
# ax.set_xlabel('column_name')

# %% [markdown]
# ## Step 4 : Feature Relationships
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Group by Comparisons
